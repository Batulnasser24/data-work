# %%
from pathlib import Path
import pandas as pd

current_dir = Path().resolve().parents[1]

file_path = current_dir / "data-work" / "data" / "processed" / "analytics_table.parquet"

df = pd.read_parquet(file_path)
df.head()
# Out:
#   order_id user_id  amount  quantity                created_at  status  \
# 0    A0001    0001    12.5       1.0 2025-12-01 10:05:00+00:00    Paid
# 1    A0002    0002     8.0       2.0 2025-12-01 11:10:00+00:00    paid
# 2    A0003    0003     NaN       1.0 2025-12-02 09:00:00+00:00  Refund
# 3    A0004    0001    25.0       NaN 2025-12-03 14:30:00+00:00    PAID
# 4    A0005    0004   100.0       1.0                       NaT    paid
#
#   status_clean  amount__isna  quantity__isna        date    year    month  \
# 0         paid         False           False  2025-12-01  2025.0  2025-12
# 1         paid         False           False  2025-12-01  2025.0  2025-12
# 2       refund          True           False  2025-12-02  2025.0  2025-12
# 3         paid         False            True  2025-12-03  2025.0  2025-12
# 4         paid         False           False        None     NaN     <NA>
#
#          dow  hour country signup_date  amount_winsor  amount__is_outlier
# 0     Monday  10.0      SA  2025-11-15         12.500               False
# 1     Monday  11.0      SA  2025-11-20          8.135               False
# 2    Tuesday   9.0      AE  2025-11-22            NaN               False
# 3  Wednesday  14.0      SA  2025-11-15         25.000               False
# 4       None   NaN      SA  2025-11-25         97.750                True

# %%
print("rows:", len(df), "cols:", len(df.columns))
print(df.dtypes.head(15))

missing = df.isna().sum().sort_values(ascending=False).head(10)
print(missing)
# Out:
# rows: 5 cols: 18
# order_id               string[python]
# user_id                string[python]
# amount                        float64
# quantity                      float64
# created_at        datetime64[ns, UTC]
# status                         object
# status_clean                   object
# amount__isna                     bool
# quantity__isna                   bool
# date                           object
# year                          float64
# month                  string[python]
# dow                            object
# hour                          float64
# country                        object
# dtype: object
# quantity         1
# amount           1
# amount_winsor    1
# dow              1
# created_at       1
# date             1
# hour             1
# year             1
# month            1
# order_id         0
# dtype: int64
